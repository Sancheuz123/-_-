# %% [markdown]
# <a href="https://colab.research.google.com/github/Sancheuz123/chiselni_metod/blob/main/%D0%93%D0%B0%D0%B9%D0%B2%D0%BE%D1%80%D0%BE%D0%BD%D1%81%D1%8C%D0%BA%D0%B8%D0%B9_%D0%9E_%D0%91%D1%96%D0%BB%D0%B5%D1%82_%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Екзаменаційна робота
# #Студента групи ФІТ 2-8
# #Гайворонського Олександра Володиморовича
# #Білет №1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, expand
x=np.array([-2.,-1.,1.,2.], dtype=float)
y=np.array([-26.,-5.,1.,10.], dtype=float)
x1 = -0.5
x2 = 0.5
x3 = 1.5
x4 = 2.5
def lagrange_interpolation(x, y, x_test):
    n = len(x)
    p = np.zeros(n)
    for i in range(n):
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (x_test - x[j])/(x[i] - x[j])
        p[i] = p_i
    return np.dot(y, p)
f1 = lagrange_interpolation(x, y, x1)
print("Значення функції у точці x_1 =", f1.round(4))
f2 = lagrange_interpolation(x, y, x2)
print("Значення функції у точці x_2 =", f2.round(4))
f3 = lagrange_interpolation(x, y, x3)
print("Значення функції у точці x_3 =", f3.round(4))
f4 = lagrange_interpolation(x, y, x4)
print("Значення функції у точці x_4 =", f4.round(4))
# Out:
# Значення функції у точці x_1 = -1.25
# Значення функції у точці x_2 = 0.25
# Значення функції у точці x_3 = 3.75
# Значення функції у точці x_4 = 21.25

# %%
xnew=np.linspace(np.min(x),np.max(x),120)
ynew=[lagrange_interpolation(x,y,i) for i in xnew]

plt.plot(x,y,'o',xnew,ynew)
plt.plot(x1,f1,'go')
plt.plot(x2,f2,'go')
plt.plot(x3,f3,'go')
plt.plot(x4,f4,'go')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Інтерполяційний багаточлен Лагранжа ')
plt.grid(True)
plt.show()

# %%
from scipy.interpolate import lagrange

f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'black', x, y, 'bo')
plt.title('Інтерполяційний багаточлен Лагранжа (Перевірка)')

plt.plot(x1,f1,'o')
plt.plot(x2,f2,'o')
plt.plot(x3,f3,'o')
plt.plot(x4,f4,'o')

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
